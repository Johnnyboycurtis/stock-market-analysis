# %%
import pandas as pd
import datetime as dt

import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-pastel')
plt.style.use('seaborn-v0_8-whitegrid')

# %%
from query_stocks import load_ticker_symbols, query_stock_prices

# %%
ticker_symbols = load_ticker_symbols(filename="stock-list.txt")
print(ticker_symbols)
# Out:
# ['VOO', 'PANW', 'AAPL', 'MSFT', 'AMZN', 'AMD', 'NVDA', 'INTU', 'FICO', 'MGK', 'SPGI', 'CRWD', 'GOOGL', 'EFIV', 'ACN', 'NFLX', 'META', 'ESGV', 'ADBE', 'XLK', 'SCHD']

# %%
price_df = query_stock_prices(tickers=ticker_symbols)
# Out:
# [*********************100%%**********************]  21 of 21 completed

# %%
price_df.tail()
# Out:
#                   AAPL         ACN        ADBE         AMD        AMZN  \
# Date
# 2024-01-12  185.919998  356.329987  596.539978  146.559998  154.619995
# 2024-01-16  183.630005  354.559998  597.679993  158.740005  153.160004
# 2024-01-17  182.679993  353.649994  596.099976  160.169998  151.710007
# 2024-01-18  188.630005  359.549988  593.700012  162.669998  153.500000
# 2024-01-19  191.559998  363.899994  611.549988  174.229996  155.339996
#
#                   CRWD       EFIV       ESGV         FICO       GOOGL  \
# Date
# 2024-01-12  283.350006  46.310001  85.110001  1230.989990  142.649994
# 2024-01-16  286.290009  46.209999  84.919998  1224.390015  142.490005
# 2024-01-17  276.269989  45.950001  84.459999  1230.160034  141.470001
# 2024-01-18  283.109985  46.330002  85.230003  1250.420044  143.479996
# 2024-01-19  290.540009  46.880001  86.400002  1260.209961  146.380005
#
#                   INTU        META         MGK        MSFT        NFLX  \
# Date
# 2024-01-12  611.799988  374.489990  261.459991  388.470001  492.160004
# 2024-01-16  603.830017  367.459991  261.279999  390.269989  481.239990
# 2024-01-17  599.840027  368.369995  259.920013  389.470001  480.329987
# 2024-01-18  611.359985  376.130005  263.720001  393.869995  485.309998
# 2024-01-19  622.179993  383.450012  268.040009  398.670013  482.950012
#
#                   NVDA        PANW       SCHD        SPGI         VOO  \
# Date
# 2024-01-12  547.099976  325.239990  76.269997  437.000000  437.989990
# 2024-01-16  563.820007  332.049988  75.709999  436.549988  436.500000
# 2024-01-17  560.530029  330.059998  75.250000  437.730011  434.070007
# 2024-01-18  571.070007  335.769989  75.699997  439.600006  437.929993
# 2024-01-19  594.909973  337.739990  76.589996  441.950012  443.290009
#
#                    XLK
# Date
# 2024-01-12  192.240005
# 2024-01-16  192.720001
# 2024-01-17  191.770004
# 2024-01-18  195.660004
# 2024-01-19  200.169998

# %%
sma_60 = price_df.rolling(50).mean()
sma_60.tail()
# Out:
#                 AAPL         ACN        ADBE       AMD      AMZN        CRWD  \
# Date
# 2024-01-12  189.0204  334.800601  596.260000  129.1166  147.2260  232.793600
# 2024-01-16  189.2136  335.879001  597.323600  130.1306  147.5492  234.952400
# 2024-01-17  189.3158  336.789601  598.071399  131.1774  147.8220  236.821800
# 2024-01-18  189.5554  337.710801  598.672200  132.1858  148.1200  238.719199
# 2024-01-19  189.8020  338.727001  599.594199  133.4354  148.4320  240.794399
#
#                 EFIV       ESGV         FICO     GOOGL        INTU      META  \
# Date
# 2024-01-12  44.67528  81.549400  1090.884004  135.3706  575.974000  337.9534
# 2024-01-16  44.77548  81.766199  1097.952004  135.6914  578.267200  339.0656
# 2024-01-17  44.85408  81.944599  1104.541405  135.9710  580.257001  340.2156
# 2024-01-18  44.93308  82.120000  1110.941606  136.2586  582.514000  341.4462
# 2024-01-19  45.01988  82.315400  1117.590605  136.5812  584.947600  342.7992
#
#                    MGK        MSFT        NFLX        NVDA        PANW  \
# Date
# 2024-01-12  251.097001  371.407602  467.371000  484.335600  281.687798
# 2024-01-16  251.757601  372.291602  468.592000  487.147000  283.431598
# 2024-01-17  252.304802  373.114601  469.704399  489.656401  285.025598
# 2024-01-18  252.886602  373.936002  470.763400  492.076801  286.870398
# 2024-01-19  253.518802  374.778802  471.727600  494.824800  288.885197
#
#                SCHD        SPGI         VOO       XLK
# Date
# 2024-01-12  73.2138  417.384402  421.945001  185.1108
# 2024-01-16  73.3650  419.087402  422.907001  185.6216
# 2024-01-17  73.4766  420.323602  423.672801  186.0568
# 2024-01-18  73.5856  421.457602  424.442601  186.5348
# 2024-01-19  73.7186  422.603602  425.304201  187.0804

# %%
sma_price_diff = 100*(price_df/ sma_60 - 1).round(3)

# %%
sma_price_diff.tail(10)
# Out:
#             AAPL  ACN  ADBE   AMD  AMZN  CRWD  EFIV  ESGV  FICO  GOOGL  INTU  \
# Date
# 2024-01-05  -3.3  2.2  -4.2  11.8   0.4  11.2   3.0   3.7   5.7    1.6   4.5
# 2024-01-08  -1.1  3.0  -1.7  17.0   2.7  16.5   4.4   5.1   8.5    3.7   5.7
# 2024-01-09  -1.5  3.4  -1.0  18.4   3.8  21.0   4.0   4.7   8.5    5.0   6.4
# 2024-01-10  -1.2  3.9  -0.4  16.9   5.0  23.5   4.3   5.1  11.6    5.7   6.6
# 2024-01-11  -1.7  4.3   0.4  15.5   5.7  23.3   4.0   4.7  12.2    5.2   6.1
# 2024-01-12  -1.6  6.4   0.0  13.5   5.0  21.7   3.7   4.4  12.8    5.4   6.2
# 2024-01-16  -3.0  5.6   0.1  22.0   3.8  21.9   3.2   3.9  11.5    5.0   4.4
# 2024-01-17  -3.5  5.0  -0.3  22.1   2.6  16.7   2.4   3.1  11.4    4.0   3.4
# 2024-01-18  -0.5  6.5  -0.8  23.1   3.6  18.6   3.1   3.8  12.6    5.3   5.0
# 2024-01-19   0.9  7.4   2.0  30.6   4.7  20.7   4.1   5.0  12.8    7.2   6.4
#
#             META  MGK  MSFT  NFLX  NVDA  PANW  SCHD  SPGI  VOO  XLK
# Date
# 2024-01-05   6.3  1.7   0.3   3.2   4.2   3.0   5.5   4.7  3.3  1.0
# 2024-01-08   7.9  3.6   2.0   5.2  10.4   5.1   5.9   5.3  4.5  3.2
# 2024-01-09   7.1  3.5   2.0   4.2  11.6   8.5   5.1   4.4  4.0  3.1
# 2024-01-10  10.5  4.4   3.6   3.1  13.5  13.6   4.8   4.7  4.3  3.6
# 2024-01-11   9.9  4.3   3.8   5.7  13.8  15.5   4.1   4.5  4.0  3.8
# 2024-01-12  10.8  4.1   4.6   5.3  13.0  15.5   4.2   4.7  3.8  3.9
# 2024-01-16   8.4  3.8   4.8   2.7  15.7  17.2   3.2   4.2  3.2  3.8
# 2024-01-17   8.3  3.0   4.4   2.3  14.5  15.8   2.4   4.1  2.5  3.1
# 2024-01-18  10.2  4.3   5.3   3.1  16.1  17.0   2.9   4.3  3.2  4.9
# 2024-01-19  11.9  5.7   6.4   2.4  20.2  16.9   3.9   4.6  4.2  7.0

# %%
last_row = sma_price_diff.iloc[-1]
last_row.name = sma_60.index[-1]
last_row.sort_values(inplace=True)

ax = last_row.plot.bar(figsize=(10, 6))
ax.set_ylim(min(-4, last_row.min() - 2),last_row.max() + 2)
ax.set_title(f"Comparisons Against 60 day Moving Average: {last_row.name.date()}")
ax.set_ylabel("%")
# Out:
# /tmp/ipykernel_7361/2642137245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_row.sort_values(inplace=True)
# Text(0, 0.5, '%')

# %%
ticker_to_plot = 'AMZN'

# %%
s1 = price_df[ticker_to_plot]
s2_ma = sma_60[ticker_to_plot].dropna()
s1 = s1.loc[s2_ma.index]

ax = s2_ma.plot(figsize = (10, 6), linewidth=2)
s1.plot(ax=ax, sharex=True, linewidth=2, linestyle="--")

ax.set_title(f"{ticker_to_plot} Price vs 60 Day Moving Average")
ax.set_ylim(s1.min()-5, s1.max()+5)
# Out:
# (114.56999969482422, 160.33999633789062)

# %%
def plot_ma(ticker_to_plot, sma_series, price_df):
    s1 = price_df[ticker_to_plot]
    s2_ma = sma_series[ticker_to_plot].dropna()
    s1 = s1.loc[s2_ma.index]

    ax = s2_ma.plot(figsize = (10, 6), linewidth=2)
    s1.plot(ax=ax, sharex=True, linewidth=2, linestyle="--")

    ax.set_title(f"{ticker_to_plot} Price vs 60 Day Moving Average")
    ax.set_ylim(s1.min()-5, s1.max()+5)
    plt.show()
    return ax

# %%
ax = plot_ma('AAPL', sma_60, price_df=price_df)

# %%
for ticker_to_plot in sorted(ticker_symbols):
    ax = plot_ma(ticker_to_plot, sma_60, price_df=price_df)

# %%
last_row.name = 'stuff'

# %%
import plotly.express as px

fig = px.bar(last_row, x=last_row.index, y=last_row)
fig.show()

# %%
df = pd.DataFrame()
df['moving_average'] = sma_60['AAPL']
df['AAPL'] = price_df['AAPL']

df = df.dropna()

# %%
fig = px.line(df)
fig.show()

# %%
df
# Out:
#             moving_average        AAPL
# Date
# 2023-09-13      185.367600  174.210007
# 2023-09-14      185.055800  175.740005
# 2023-09-15      184.719800  175.009995
# 2023-09-18      184.465601  177.970001
# 2023-09-19      184.274801  179.070007
# ...                    ...         ...
# 2024-01-12      189.020400  185.919998
# 2024-01-16      189.213600  183.630005
# 2024-01-17      189.315800  182.679993
# 2024-01-18      189.555400  188.630005
# 2024-01-19      189.802000  191.559998
#
# [89 rows x 2 columns]

# %%
# https://plotly.com/python/time-series/

from dash import Dash, dcc, html, Input, Output
import plotly.express as px

app = Dash(__name__)


app.layout = html.Div([
    html.H4('Stock price analysis'),
    dcc.Graph(id="time-series-chart"),
    html.P("Select stock:"),
    dcc.Dropdown(
        id="ticker",
        options=ticker_symbols,
        value="AAPL",
        clearable=False,
    ),
])


@app.callback(
    Output("time-series-chart", "figure"), 
    Input("ticker", "value"))


def display_time_series(ticker):
    df = pd.DataFrame()
    df['MA(50)'] = sma_60[ticker]
    df[ticker] = price_df[ticker]

    df = df.dropna()
    fig = px.line(df)
    return fig


app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
